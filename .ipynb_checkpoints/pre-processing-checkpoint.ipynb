# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# __Data Import:__

# %%
data = pd.read_csv('hq_bookings.csv')

# %%
data.head()
# Out:
#   Booking_Date  Order_Amount Check_In_Date  Length_of_Stay_In_Nights  \
# 0     1/1/2018          1435      1/2/2018                         4
# 1     1/1/2018            70      1/2/2018                         1
# 2     1/1/2018           284      1/3/2018                         2
# 3     1/1/2018           173      1/2/2018                         1
# 4     1/1/2018          2314      3/5/2018                         5
#
#   Order_Status User_Country_Name Hotel_Country_Name    Platform
# 0       Active          Thailand           Thailand  Platform 2
# 1       Active             Italy              Italy  Platform 2
# 2       Active           Germany            Germany  Platform 2
# 3       Active           Germany            Germany  Platform 2
# 4       Active            France         Seychelles  Platform 2

# %%
data.describe()
# Out:
#         Order_Amount  Length_of_Stay_In_Nights
# count  126677.000000             126677.000000
# mean      440.335033                  2.104013
# std       558.819277                  1.843886
# min        15.000000                  1.000000
# 25%       149.000000                  1.000000
# 50%       264.000000                  1.000000
# 75%       508.000000                  3.000000
# max     16634.000000                 58.000000

# %%
print ('Number of rows before removing the Unconfirmed row:', len(data))
# Out:
# Number of rows before removing the Unconfirmed row: 126677

# %% [markdown]
# __Platform column simplified:__

# %%
data = data.replace({'Platform 1': 1, 'Platform 2': 2, 'Platform 3':3})

# %% [markdown]
# __one row out of 126K rows had an Unconfirmed status, removed:__

# %%
data = data[data.Order_Status != 'Unconfirmed']

# %%
print ('Number of rows before After the Unconfirmed row:', len(data))
# Out:
# Number of rows before After the Unconfirmed row: 126676

# %% [markdown]
# __ReIndexing:__

# %%
data.index = range(len(data))

# %%
data.head()
# Out:
#   Booking_Date  Order_Amount Check_In_Date  Length_of_Stay_In_Nights  \
# 0     1/1/2018          1435      1/2/2018                         4
# 1     1/1/2018            70      1/2/2018                         1
# 2     1/1/2018           284      1/3/2018                         2
# 3     1/1/2018           173      1/2/2018                         1
# 4     1/1/2018          2314      3/5/2018                         5
#
#   Order_Status User_Country_Name Hotel_Country_Name  Platform
# 0       Active          Thailand           Thailand         2
# 1       Active             Italy              Italy         2
# 2       Active           Germany            Germany         2
# 3       Active           Germany            Germany         2
# 4       Active            France         Seychelles         2

# %% [markdown]
# __Adding  rows of Booking_Month and Booking_Day:__

# %%
booking_zeros =  pd.DataFrame(np.zeros((len(data), 1)))
data.insert(loc=1, column='Booking_Day', value=booking_zeros)
data.insert(loc=1, column='Booking_Month', value=booking_zeros)

# %% [markdown]
# __Cutting the value of day from the date:__

# %%
data['Booking_Day'] = data['Booking_Date'].apply(lambda st: st[st.find("/")+1:st.rfind("/")])

# %% [markdown]
# __Cutting the value of month from the date:__

# %%
data['Booking_Month'] = [x.split('/')[0] for x in data['Booking_Date']]

# %%
data.tail()
# Out:
#        Booking_Date Booking_Month Booking_Day  Order_Amount Check_In_Date  \
# 126671    4/30/2018             4          30            49     5/22/2018
# 126672    4/30/2018             4          30            80     4/30/2018
# 126673    4/30/2018             4          30           188     8/18/2018
# 126674    4/30/2018             4          30            54     5/11/2018
# 126675    4/30/2018             4          30           138     5/31/2018
#
#         Length_of_Stay_In_Nights Order_Status User_Country_Name  \
# 126671                         1       Active            Brazil
# 126672                         1       Active            France
# 126673                         3       Active            Brazil
# 126674                         1       Active             Spain
# 126675                         1       Active     United States
#
#        Hotel_Country_Name  Platform
# 126671             Brazil         2
# 126672             France         2
# 126673             Brazil         2
# 126674              Spain         2
# 126675      United States         2

# %% [markdown]
# __Adding  rows of Checkin_Month and Checkin_Day:__

# %%
checkin_zeros =  pd.DataFrame(np.zeros((len(data), 1)))
data.insert(loc=5, column='Checkin_Day', value=booking_zeros)
data.insert(loc=5, column='Checkin_Month', value=booking_zeros)

# %%
data.head()
# Out:
#   Booking_Date Booking_Month Booking_Day  Order_Amount Check_In_Date  \
# 0     1/1/2018             1           1          1435      1/2/2018
# 1     1/1/2018             1           1            70      1/2/2018
# 2     1/1/2018             1           1           284      1/3/2018
# 3     1/1/2018             1           1           173      1/2/2018
# 4     1/1/2018             1           1          2314      3/5/2018
#
#    Checkin_Month  Checkin_Day  Length_of_Stay_In_Nights Order_Status  \
# 0            0.0          0.0                         4       Active
# 1            0.0          0.0                         1       Active
# 2            0.0          0.0                         2       Active
# 3            0.0          0.0                         1       Active
# 4            0.0          0.0                         5       Active
#
#   User_Country_Name Hotel_Country_Name  Platform
# 0          Thailand           Thailand         2
# 1             Italy              Italy         2
# 2           Germany            Germany         2
# 3           Germany            Germany         2
# 4            France         Seychelles         2

# %% [markdown]
# __Cutting the value of day from the date:__

# %%
data['Checkin_Day'] = data['Check_In_Date'].apply(lambda st: st[st.find("/")+1:st.rfind("/")])

# %% [markdown]
# __Cutting the value of month from the date:__

# %%
data['Checkin_Month'] = [x.split('/')[0] for x in data['Check_In_Date']]

# %%
data.tail()
# Out:
#        Booking_Date Booking_Month Booking_Day  Order_Amount Check_In_Date  \
# 126671    4/30/2018             4          30            49     5/22/2018
# 126672    4/30/2018             4          30            80     4/30/2018
# 126673    4/30/2018             4          30           188     8/18/2018
# 126674    4/30/2018             4          30            54     5/11/2018
# 126675    4/30/2018             4          30           138     5/31/2018
#
#        Checkin_Month Checkin_Day  Length_of_Stay_In_Nights Order_Status  \
# 126671             5          22                         1       Active
# 126672             4          30                         1       Active
# 126673             8          18                         3       Active
# 126674             5          11                         1       Active
# 126675             5          31                         1       Active
#
#        User_Country_Name Hotel_Country_Name  Platform
# 126671            Brazil             Brazil         2
# 126672            France             France         2
# 126673            Brazil             Brazil         2
# 126674             Spain              Spain         2
# 126675     United States      United States         2

# %% [markdown]
# __Adding a new column for total_days:__

# %%
checkin_zeros =  pd.DataFrame(np.zeros((len(data), 1)))
data.insert(loc=7, column='Total_Days', value=booking_zeros)

# %%
data.tail()
# Out:
#        Booking_Date Booking_Month Booking_Day  Order_Amount Check_In_Date  \
# 126671    4/30/2018             4          30            49     5/22/2018
# 126672    4/30/2018             4          30            80     4/30/2018
# 126673    4/30/2018             4          30           188     8/18/2018
# 126674    4/30/2018             4          30            54     5/11/2018
# 126675    4/30/2018             4          30           138     5/31/2018
#
#        Checkin_Month Checkin_Day  Total_Days  Length_of_Stay_In_Nights  \
# 126671             5          22         0.0                         1
# 126672             4          30         0.0                         1
# 126673             8          18         0.0                         3
# 126674             5          11         0.0                         1
# 126675             5          31         0.0                         1
#
#        Order_Status User_Country_Name Hotel_Country_Name  Platform
# 126671       Active            Brazil             Brazil         2
# 126672       Active            France             France         2
# 126673       Active            Brazil             Brazil         2
# 126674       Active             Spain              Spain         2
# 126675       Active     United States      United States         2

# %% [markdown]
# __Total days calculated by order amount, times length of each stay:__

# %%
data['Total_Days'] = data.Order_Amount * data.Length_of_Stay_In_Nights

# %%
data.head()
# Out:
#   Booking_Date Booking_Month Booking_Day  Order_Amount Check_In_Date  \
# 0     1/1/2018             1           1          1435      1/2/2018
# 1     1/1/2018             1           1            70      1/2/2018
# 2     1/1/2018             1           1           284      1/3/2018
# 3     1/1/2018             1           1           173      1/2/2018
# 4     1/1/2018             1           1          2314      3/5/2018
#
#   Checkin_Month Checkin_Day  Total_Days  Length_of_Stay_In_Nights  \
# 0             1           2        5740                         4
# 1             1           2          70                         1
# 2             1           3         568                         2
# 3             1           2         173                         1
# 4             3           5       11570                         5
#
#   Order_Status User_Country_Name Hotel_Country_Name  Platform
# 0       Active          Thailand           Thailand         2
# 1       Active             Italy              Italy         2
# 2       Active           Germany            Germany         2
# 3       Active           Germany            Germany         2
# 4       Active            France         Seychelles         2

# %% [markdown]
# __ Countries ranking based on the summation of days all people from the same country booked in all 4 months:__

# %%
rank = data.groupby('User_Country_Name')['Total_Days'].agg({'Total_Days':'sum'})
rank = rank.sort_values(by=['Total_Days'], ascending= False).reset_index()
rank
# Out:
# c:\users\mojiway\appdata\local\programs\python\python36-32\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   """Entry point for launching an IPython kernel.
#             User_Country_Name  Total_Days
# 0               United States    76011654
# 1                   Australia    34550535
# 2                     Germany    13017211
# 3              United Kingdom    11340714
# 4                      Canada     5327788
# 5                      France     4932744
# 6                 South Korea     4390787
# 7                       Italy     4255267
# 8                      Brazil     3907063
# 9                 New Zealand     3817841
# 10                      Spain     3316558
# 11                      Japan     2808701
# 12                  Singapore     2753057
# 13                   Thailand     2147380
# 14                     Mexico     2018016
# 15                  Hong Kong     1756926
# 16                      India     1569358
# 17                Philippines     1469174
# 18                    Ireland     1442160
# 19                     Norway     1314866
# 20                   Malaysia     1170856
# 21                  Argentina     1091125
# 22                    Austria     1083006
# 23                Netherlands     1062306
# 24                Switzerland      734774
# 25                     Russia      694843
# 26                  Indonesia      656304
# 27                     Taiwan      634458
# 28                   Portugal      512759
# 29       United Arab Emirates      490298
# ..                        ...         ...
# 90                    Romania        3120
# 91                 Seychelles        2810
# 92                 Kazakhstan        2792
# 93                      Chile        2300
# 94                  Nicaragua        1897
# 95                    Jamaica        1776
# 96                  Sri Lanka        1547
# 97                     Serbia        1444
# 98   Northern Mariana Islands        1421
# 99                     Jersey        1395
# 100                   Albania        1388
# 101                 Guatemala        1275
# 102                     Ghana        1086
# 103                     Aruba         885
# 104                   Bahamas         838
# 105                   Tunisia         778
# 106                Martinique         674
# 107                     Niger         591
# 108                     Egypt         500
# 109                      Iraq         490
# 110                Bangladesh         418
# 111                  Botswana         372
# 112                  Suriname         360
# 113                  Ethiopia         286
# 114                  Maldives         281
# 115                Azerbaijan         260
# 116                      Peru         220
# 117                San Marino         153
# 118                Mozambique         129
# 119        Dominican Republic         122
#
# [120 rows x 2 columns]

# %% [markdown]
# __For this is just a test, we keep the first 20 countries only and work on them:__

# %%
rank = rank.head(20)
rank
# Out:
#    User_Country_Name  Total_Days
# 0      United States    76011654
# 1          Australia    34550535
# 2            Germany    13017211
# 3     United Kingdom    11340714
# 4             Canada     5327788
# 5             France     4932744
# 6        South Korea     4390787
# 7              Italy     4255267
# 8             Brazil     3907063
# 9        New Zealand     3817841
# 10             Spain     3316558
# 11             Japan     2808701
# 12         Singapore     2753057
# 13          Thailand     2147380
# 14            Mexico     2018016
# 15         Hong Kong     1756926
# 16             India     1569358
# 17       Philippines     1469174
# 18           Ireland     1442160
# 19            Norway     1314866

# %% [markdown]
# __new dataset with top 20 countries:__

# %%
top_countries = rank['User_Country_Name'].tolist()
new_data = data.loc[data['User_Country_Name'].isin(top_countries)]
new_data.size
# Out:
# 1540214

# %%
rank_active_vs_cancelled = new_data.pivot_table(index='Order_Status',columns='User_Country_Name',values='Total_Days').transpose()
rank_active_vs_cancelled =  rank_active_vs_cancelled.fillna(0).astype(int)
rank_active_vs_cancelled['percentage'] = ((rank_active_vs_cancelled['Active'] / rank_active_vs_cancelled['Cancelled']) * 100).astype(int)

rank_active_vs_cancelled
# Out:
# Order_Status       Active  Cancelled  percentage
# User_Country_Name
# Australia            2041       3167          64
# Brazil               1112       2049          54
# Canada               1553       2206          70
# France                961       2300          41
# Germany              1553       2220          69
# Hong Kong            1436       1919          74
# India                1256       1400          89
# Ireland              1680       1487         112
# Italy                1195       2108          56
# Japan                1897       3931          48
# Mexico               1028       1116          92
# New Zealand          1366       2739          49
# Norway               2420       5958          40
# Philippines           880       1952          45
# Singapore             927       1460          63
# South Korea          1442       2174          66
# Spain                 992       1855          53
# Thailand             1111       1738          63
# United Kingdom       1782       3966          44
# United States        1347       2105          63

# %%
top_deals_active = top_deals[top_deals['Order_Status'] == 'Active']

# %%
top_deals_cancelled = top_deals[top_deals['Order_Status'] == 'Cancelled']

# %%
top_deals_cancelled
# Out:
#        Booking_Date Booking_Month Booking_Day  Order_Amount Check_In_Date  \
# 29         1/1/2018             1           1          2465     3/11/2018
# 181        1/1/2018             1           1          4059    12/29/2018
# 235        1/1/2018             1           1          2433     2/17/2018
# 256        1/1/2018             1           1          1925    12/28/2018
# 257        1/1/2018             1           1          1907    12/28/2018
# 266        1/1/2018             1           1          4491      2/2/2018
# 271        1/1/2018             1           1          3751     1/10/2018
# 294        1/1/2018             1           1          8455     2/17/2018
# 446        1/1/2018             1           1          2303     1/20/2018
# 931        1/2/2018             1           2          2687      7/7/2018
# 1477       1/3/2018             1           3          5580     2/22/2018
# 1565       1/3/2018             1           3          2169      2/5/2018
# 1699       1/3/2018             1           3          1665     6/10/2018
# 117538    Cancelled            France              Thailand         2
# 117828    Cancelled     United States                Greece         2
# 117875    Cancelled         Australia             Indonesia         2
# 118235    Cancelled            Canada             Hong Kong         2
# 118715    Cancelled             Italy                 Spain         2
# 119365    Cancelled     United States                Russia         2
# 119397    Cancelled     United States                Brazil         2
# 119601    Cancelled     United States      Turks and Caicos         2
# 120119    Cancelled         Australia             Australia         2
# 120304    Cancelled         Australia             Australia         2
# 120355    Cancelled     United States         United States         2
# 120425    Cancelled    United Kingdom                 Egypt         2
# 120612    Cancelled    United Kingdom              Ethiopia         2
# 120758    Cancelled     United States              Portugal         2
# 121441    Cancelled     United States              Thailand         2
# 121859    Cancelled     United States         United States         2
# 123922    Cancelled    United Kingdom                 Italy         2
# 124641    Cancelled     United States                 Japan         2
# 124644    Cancelled             Spain                 Spain         2
# 124837    Cancelled    United Kingdom                 Spain         2
# 125149    Cancelled            Brazil              Portugal         2
# 125745    Cancelled             Spain                 Spain         2
# 126404    Cancelled         Australia                 Japan         2
#
# [653 rows x 13 columns]

# %%
top_deals_active
# Out:
#        Booking_Date Booking_Month Booking_Day  Order_Amount Check_In_Date  \
# 4          1/1/2018             1           1          2314      3/5/2018
# 38         1/1/2018             1           1          3633      2/1/2018
# 63         1/1/2018             1           1          1559      3/8/2018
# 65         1/1/2018             1           1          2085     1/26/2018
# 83         1/1/2018             1           1          1607      1/2/2018
# 130        1/1/2018             1           1          2432     3/24/2018
# 135        1/1/2018             1           1          3288     2/17/2018
# 192        1/1/2018             1           1          2281      7/1/2018
# 254        1/1/2018             1           1          1472     12/1/2018
# 276        1/1/2018             1           1          2065     3/26/2018
# 368        1/1/2018             1           1          1962     12/1/2018
# 384        1/1/2018             1           1          2276      3/4/2018
# 398        1/1/2018             1           1          4124     2/20/2018
# 403        1/1/2018             1           1          3808     7/31/2018
# 458        1/1/2018             1           1          1918      1/1/2018
# 487        1/1/2018             1           1          2772     2/15/2018
# 505        1/1/2018             1           1          5088      6/4/2018
# 527        1/1/2018             1           1          1740      1/8/2018
# 610        1/1/2018             1           1          2611      3/9/2018
# 638        1/1/2018             1           1          6806    12/22/2018
# 646        1/1/2018             1           1          2179     3/25/2018
# 722        1/2/2018             1           2          1393     5/24/2018
# 723        1/2/2018             1           2          2808    12/29/2018
# 743        1/2/2018             1           2          2575    11/18/2018
# 750        1/2/2018             1           2          2889     6/18/2018
# 784        1/2/2018             1           2          3030     2/23/2018
# 797        1/2/2018             1           2         10523      3/7/2018
# 799        1/2/2018             1           2          2411     1/24/2018
# 807        1/2/2018             1           2          2175     1/22/2018
# 897        1/2/2018             1           2          2028     1/17/2018
# ...             ...           ...         ...           ...           ...
# 125276    4/29/2018             4          29           992     8/10/2018
# 125284    4/29/2018             4          29          3317    11/10/2018
# 125382    4/29/2018             4          29          2681     7/17/2018
# 125407    4/29/2018             4          29          1907    11/19/2018
# 125410    4/29/2018             4          29          4817      9/5/2018
# 125586    4/30/2018             4          30          2084      5/7/2018
# 125640    4/30/2018             4          30          5104     7/14/2018
# 126650             5           9       10804                         4
#
#        Order_Status User_Country_Name Hotel_Country_Name  Platform
# 4            Active            France         Seychelles         2
# 38           Active     United States             Mexico         2
# 63           Active            Canada          Hong Kong         2
# 65           Active             Italy             France         2
# 83           Active     United States            Vietnam         2
# 130          Active           Germany         Cape Verde         2
# 135          Active           Ireland          Sri Lanka         2
# 192          Active           Germany             Latvia         2
# 254          Active         Australia           Thailand         2
# 276          Active    United Kingdom      United States         2
# 368          Active         Australia           Thailand         2
# 384          Active           Germany            Germany         2
# 398          Active     United States             Mexico         2
# 403          Active          Thailand           Thailand         2
# 458          Active     United States      United States         2
# 487          Active         Australia          Australia         2
# 505          Active     United States      United States         2
# 527          Active           Vietnam            Vietnam         2
# 610          Active     United States           Colombia         2
# 638          Active         Australia     Czech Republic         2
# 646          Active     United States             Mexico         2
# 722          Active         Australia            Vietnam         2
# 723          Active             Japan           Malaysia         2
# 743          Active    United Kingdom           Barbados         2
# 750          Active     United States      United States         2
# 784          Active    United Kingdom              India         2
# 797          Active         Australia          Australia         2
# 799          Active    United Kingdom              Spain         2
# 807          Active         Australia           Thailand         2
# 897          Active    United Kingdom           Thailand         2
# ...             ...               ...                ...       ...
# 125276       Active         Australia           Thailand         2
# 125284       Active     United States          Hong Kong         2
# 125382       Active     United States      United States         2
# 125407       Active         Australia      United States         2
# 125410       Active         Australia          Indonesia         2
# 125586       Active    United Kingdom           Tanzania         2
# 125640       Active         Australia              Italy         2
# 125699       Active       Philippines     Czech Republic         2
# 125706       Active           Germany        Switzerland         2
# 125759       Active     United States      United States         2
# 125805       Active       New Zealand          Australia         2
# 125893       Active     United States              Japan         2
# 125968       Active    United Kingdom              Spain         2
# 126017       Active     United States      United States         2
# 126069       Active     United States      United States         2
# 126077       Active     United States      United States         2
# 126080       Active         Australia          Australia         2
# 126164       Active             Japan             Taiwan         1
# 126178       Active     United States              Egypt         2
# 126234       Active     United States              Japan         2
# 126238       Active     United States      United States         2
# 126245       Active     United States           Barbados         2
# 126291       Active       South Korea      United States         2
# 126310       Active     United States      United States         2
# 126375       Active     United States      United States         2
# 126427       Active             Spain      United States         2
# 126498       Active     United States              Italy         2
# 126555       Active     United States             Mexico         2
# 126604       Active         Australia              Spain         2
# 126650       Active             Italy     United Kingdom         2
#
# [2526 rows x 13 columns]

# %%
top_deals_active.to_csv('top_deals_active.csv')

# %%
top_deals_cancelled.to_csv('top_deals_cancelled.csv')

# %%
top_deals.to_csv('top_deals.csv')

# %%
data.to_csv('pre-processed-for-visualization.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-461-c4a2889fe463> in <module>()
# ----> 1 data.to_csv('pre-processed-for-visualization.csv')
#
# c:\users\mojiway\appdata\local\programs\python\python36-32\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1522                                      doublequote=doublequote,
#    1523                                      escapechar=escapechar, decimal=decimal)
# -> 1524         formatter.save()
#    1525
#    1526         if path_or_buf is None:
#
# c:\users\mojiway\appdata\local\programs\python\python36-32\lib\site-packages\pandas\io\formats\format.py in save(self)
#    1635             f, handles = _get_handle(self.path_or_buf, self.mode,
#    1636                                      encoding=encoding,
# -> 1637                                      compression=self.compression)
#    1638             close = True
#    1639
#
# c:\users\mojiway\appdata\local\programs\python\python36-32\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     388         elif encoding:
#     389             # Python 3 and encoding
# --> 390             f = open(path_or_buf, mode, encoding=encoding)
#     391         elif is_text:
#     392             # Python 3 and no explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'pre-processed-for-visualization.csv'

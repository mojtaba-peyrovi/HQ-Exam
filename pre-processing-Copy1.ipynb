# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# __Data Import:__

# %%
data = pd.read_csv('hq_bookings.csv')

# %%
data.head()
# Out:
#   Booking_Date  Order_Amount Check_In_Date  Length_of_Stay_In_Nights  \
# 0     1/1/2018          1435      1/2/2018                         4
# 1     1/1/2018            70      1/2/2018                         1
# 2     1/1/2018           284      1/3/2018                         2
# 3     1/1/2018           173      1/2/2018                         1
# 4     1/1/2018          2314      3/5/2018                         5
#
#   Order_Status User_Country_Name Hotel_Country_Name    Platform
# 0       Active          Thailand           Thailand  Platform 2
# 1       Active             Italy              Italy  Platform 2
# 2       Active           Germany            Germany  Platform 2
# 3       Active           Germany            Germany  Platform 2
# 4       Active            France         Seychelles  Platform 2

# %%
data.describe()
# Out:
#         Order_Amount  Length_of_Stay_In_Nights
# count  126677.000000             126677.000000
# mean      440.335033                  2.104013
# std       558.819277                  1.843886
# min        15.000000                  1.000000
# 25%       149.000000                  1.000000
# 50%       264.000000                  1.000000
# 75%       508.000000                  3.000000
# max     16634.000000                 58.000000

# %%
print ('Number of rows before removing the Unconfirmed row:', len(data))
# Out:
# Number of rows before removing the Unconfirmed row: 126677

# %% [markdown]
# __Platform column simplified:__

# %%
data = data.replace({'Platform 1': 1, 'Platform 2': 2, 'Platform 3':3})

# %% [markdown]
# __one row out of 126K rows had an Unconfirmed status, removed:__

# %%
data = data[data.Order_Status != 'Unconfirmed']

# %%
print ('Number of rows before After the Unconfirmed row:', len(data))
# Out:
# Number of rows before After the Unconfirmed row: 126676

# %% [markdown]
# __ReIndexing:__

# %%
data.index = range(len(data))

# %%
data.head()
# Out:
#   Booking_Date  Order_Amount Check_In_Date  Length_of_Stay_In_Nights  \
# 0     1/1/2018          1435      1/2/2018                         4
# 1     1/1/2018            70      1/2/2018                         1
# 2     1/1/2018           284      1/3/2018                         2
# 3     1/1/2018           173      1/2/2018                         1
# 4     1/1/2018          2314      3/5/2018                         5
#
#   Order_Status User_Country_Name Hotel_Country_Name  Platform
# 0       Active          Thailand           Thailand         2
# 1       Active             Italy              Italy         2
# 2       Active           Germany            Germany         2
# 3       Active           Germany            Germany         2
# 4       Active            France         Seychelles         2

# %% [markdown]
# __Adding  rows of Booking_Month and Booking_Day:__

# %%
booking_zeros =  pd.DataFrame(np.zeros((len(data), 1)))
data.insert(loc=1, column='Booking_Day', value=booking_zeros)
data.insert(loc=1, column='Booking_Month', value=booking_zeros)

# %% [markdown]
# __Cutting the value of day from the date:__

# %%
data['Booking_Day'] = data['Booking_Date'].apply(lambda st: st[st.find("/")+1:st.rfind("/")])

# %% [markdown]
# __Cutting the value of month from the date:__

# %%
data['Booking_Month'] = [x.split('/')[0] for x in data['Booking_Date']]

# %%
data.tail()
# Out:
#        Booking_Date Booking_Month Booking_Day  Order_Amount Check_In_Date  \
# 126671    4/30/2018             4          30            49     5/22/2018
# 126672    4/30/2018             4          30            80     4/30/2018
# 126673    4/30/2018             4          30           188     8/18/2018
# 126674    4/30/2018             4          30            54     5/11/2018
# 126675    4/30/2018             4          30           138     5/31/2018
#
#         Length_of_Stay_In_Nights Order_Status User_Country_Name  \
# 126671                         1       Active            Brazil
# 126672                         1       Active            France
# 126673                         3       Active            Brazil
# 126674                         1       Active             Spain
# 126675                         1       Active     United States
#
#        Hotel_Country_Name  Platform
# 126671             Brazil         2
# 126672             France         2
# 126673             Brazil         2
# 126674              Spain         2
# 126675      United States         2

# %% [markdown]
# __Adding  rows of Checkin_Month and Checkin_Day:__

# %%
checkin_zeros =  pd.DataFrame(np.zeros((len(data), 1)))
data.insert(loc=5, column='Checkin_Day', value=booking_zeros)
data.insert(loc=5, column='Checkin_Month', value=booking_zeros)

# %%
data.head()
# Out:
#   Booking_Date Booking_Month Booking_Day  Order_Amount Check_In_Date  \
# 0     1/1/2018             1           1          1435      1/2/2018
# 1     1/1/2018             1           1            70      1/2/2018
# 2     1/1/2018             1           1           284      1/3/2018
# 3     1/1/2018             1           1           173      1/2/2018
# 4     1/1/2018             1           1          2314      3/5/2018
#
#    Checkin_Month  Checkin_Day  Length_of_Stay_In_Nights Order_Status  \
# 0            0.0          0.0                         4       Active
# 1            0.0          0.0                         1       Active
# 2            0.0          0.0                         2       Active
# 3            0.0          0.0                         1       Active
# 4            0.0          0.0                         5       Active
#
#   User_Country_Name Hotel_Country_Name  Platform
# 0          Thailand           Thailand         2
# 1             Italy              Italy         2
# 2           Germany            Germany         2
# 3           Germany            Germany         2
# 4            France         Seychelles         2

# %% [markdown]
# __Cutting the value of day from the date:__

# %%
data['Checkin_Day'] = data['Check_In_Date'].apply(lambda st: st[st.find("/")+1:st.rfind("/")])

# %% [markdown]
# __Cutting the value of month from the date:__

# %%
data['Checkin_Month'] = [x.split('/')[0] for x in data['Check_In_Date']]

# %%
data.tail()
# Out:
#        Booking_Date Booking_Month Booking_Day  Order_Amount Check_In_Date  \
# 126671    4/30/2018             4          30            49     5/22/2018
# 126672    4/30/2018             4          30            80     4/30/2018
# 126673    4/30/2018             4          30           188     8/18/2018
# 126674    4/30/2018             4          30            54     5/11/2018
# 126675    4/30/2018             4          30           138     5/31/2018
#
#        Checkin_Month Checkin_Day  Length_of_Stay_In_Nights Order_Status  \
# 126671             5          22                         1       Active
# 126672             4          30                         1       Active
# 126673             8          18                         3       Active
# 126674             5          11                         1       Active
# 126675             5          31                         1       Active
#
#        User_Country_Name Hotel_Country_Name  Platform
# 126671            Brazil             Brazil         2
# 126672            France             France         2
# 126673            Brazil             Brazil         2
# 126674             Spain              Spain         2
# 126675     United States      United States         2
